# %%
import pandas as pd

# %%
df = pd.read_csv('/home/rijand/Downloads/species_list_pw.tsv',sep='\t')

# %%
df1 = df.iloc[:,[0,3]]

# %%
df1
# Out:
#                  Unnamed: 0  homosporous (1 for yes)
# 0      Acacia argyrophylla                       NaN
# 1       Adiantum raddianum                       1.0
# 2          Agave tequilana                       NaN
# 3     Amborella trichopoda                       NaN
# 4         Anemia tomentosa                       1.0
# ..                      ...                      ...
# 105      Torreya taxifolia                       NaN
# 106  Vittaria appalachiana                       1.0
# 107       Wollemia nobilis                       NaN
# 108                Zea may                       NaN
# 109    Zingiber officinale                       NaN
#
# [110 rows x 2 columns]

# %%
df1.dropna()
# Out:
#                           Unnamed: 0  homosporous (1 for yes)
# 1                Adiantum raddianum                       1.0
# 4                  Anemia tomentosa                       1.0
# 9             Asplenium platyneuron                       1.0
# 18       Ceratopteris thalictroides                       1.0
# 22            Cystopteris utahensis                       1.0
# 23                    Danaea nodosa                       1.0
# 25        Dennstaedtia davallioides                       1.0
# 28          Diphasiastrum digitatum                       1.0
# 29               Dipteris conjugata                       1.0
# 34               Equisetum diffusum                       1.0
# 35                Equisetum hyemale                       1.0
# 45                Huperzia lucidula                       1.0
# 46              Huperzia myrsinites                       1.0
# 47               Huperzia squarrosa                       1.0
# ...
